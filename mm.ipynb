# %%
from matplotlib import pyplot
import pymongo

client = pymongo.MongoClient("mongodb+srv://aditya:aditya@cluster0.jnyunbc.mongodb.net/?retryWrites=true&w=majority")
db = client['device_data']

data = db.get_collection('pulse_rate').find({})

heart_rate = []
time = []

n = 0

for d in data:
    if n > 6000:
        break
    
    heart_rate.append(d['heart_pulse'])
    time.append(d['timestamp']/1000000000)
    n += 1

fig, ax = pyplot.subplots()

pyplot.plot(time, heart_rate)

image_format = 'svg' # e.g .png, .svg, etc.
image_name = 'myimage.svg'

fig.savefig(image_name, format=image_format, dpi=1200)
